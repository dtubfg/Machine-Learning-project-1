# %% [markdown]
# # Principle Component analysis of crowdfunding projects
# Data visualization of Kickstarter projects based on suitable visualization techniques including a principal component analysis (PCA).
#
# The dataset was downloaded from
# https://www.kaggle.com/kemical/kickstarter-projects
# on September 14th 2018.

# %%
# Run this cell first to apply the style to the notebook
from IPython.core.display import HTML
css_file = './31380.css'
HTML(open(css_file, "r").read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-2a3a2bc61751> in <module>()
#       2 from IPython.core.display import HTML
#       3 css_file = './data.css'
# ----> 4 HTML(open(css_file, "r").read())
#
# FileNotFoundError: [Errno 2] No such file or directory: './data.css'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.linalg import svd
# %matplotlib inline

# %%
# create the dataframe and define a reduced version with the first 
# 5000 observations of project goal and the total amount pledged
raw_data = pd.read_csv('data.csv')
cols = ['goal', 'pledged']
df = pd.DataFrame(raw_data, columns = cols)
df_training = df[0:5000] # real training set: df[0:250000]
# df_testing = df[250000:]

# compute (reduced) dataframe dimensions (X = N x M)
N = len(df['goal'])
M = len(cols)

# %%
# plot a simple relationship
fig, ax = plt.subplots(figsize=(5,5))
ax.set(title='5000 projects up to 100k USD',
      xlabel='Project goal [USD]', ylabel='Money pledged [USD]',
      xlim=[0, 100000], ylim=[0, 100000])
ax.scatter(df_training['goal'], df_training['pledged'], alpha=0.5)
ax.plot(df_training['goal'], df_training['goal'], color='black', linewidth=1, label='Threshold')
ax.legend()
# idea: split dataset
success_mask = [df_training['pledged'] >= df_training['goal']]
# 'succeeded'-color blue, else 'failed'-red

# %%
# Subtract mean value from data
Y = X - X.mean(axis=0)

# PCA by computing SVD of Y
U,S,V = svd(Y,full_matrices=False)
# print('U[0] = ', U[0], '\nS[0] =', S[0], '\nV[0] =', V[0])

# Compute variance explained by principal components
rho = (S**2) / (S**2).sum()

# Plot variance explained
fig, ax = plt.subplots(ncols=2)
ax1.plot(range(1,len(rho)+1),rho,'o-')
ax1.set(title='Variance explained by principal components', 
        xlabel='Principal component', ylabel='Variance explained')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-517ece4e4e28> in <module>()
#       1 # Subtract mean value from data
# ----> 2 Y = X - X.mean(axis=0)
#       3
#       4 # PCA by computing SVD of Y
#       5 U,S,V = svd(Y,full_matrices=False)
#
# NameError: name 'X' is not defined

# %% [markdown]
# It is possible to use standard LaTeX code to visualize formulas nicely:
#
# $$y+2x^2 = 2\pi$$
#
# $$\sum\limits_{x=1}^{\infty} {1 \over x} = 2$$

# %% [markdown]
# # Duration and year.

# %% [markdown]
# # Correlations and normal distributions

# %%
#Make a scatter matrix over the important variable/attributes
from pandas.plotting import scatter_matrix
import seaborn as sns
#raw_data = pd.read_csv('data.csv')
import datetime as dt

list(raw_data.columns.values)
cols = ['launched', 'deadline','usd_goal_real','backers','usd_pledged_real','state']
df = pd.DataFrame(raw_data, columns = cols)
#Parse the the two date times as datetime, apparently that is needed to find the difference in time
df['launched'] = pd.to_datetime(df['launched'])
df['deadline'] = pd.to_datetime(df['deadline'])
# So this how you get the year so there might not be any reason to make any new coloum
df['yearlaunched'] = pd.DatetimeIndex(df['launched']).year
#Make a new coloum with the new duration
df['duration']=pd.Series((df['deadline'] - df['launched']), index=df.index)
df['durationdays']=pd.DatetimeIndex(df['duration']).day
#List of corralation worthy variables:'goal','backers','pledged' Selfmade:'durationdays','yearlaunched'
pltdf = df[['usd_goal_real','backers','usd_pledged_real','durationdays','yearlaunched','state']].copy()
#pltdf_norm = (pltdf - pltdf.mean()) / (pltdf.max() - pltdf.min())
#print(df['yearlaunched'])
#pltdf.hist()
#df = pd.DataFrame(raw_data)
#scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
#sns_plot=sns.pairplot(pltdf[0:50000], hue='state')
#sns_plot.savefig("output2.png")
#scatter_matrix(pltdf[0:10000], alpha=0.2, diagonal='hist')
pltdf['usd_goal_real_log']=np.log(pltdf['usd_goal_real'])
pltdf['usd_goal_real_log'].hist(bins=100,log=True)
plt.figure()
pltdf['backers_log']=np.log(pltdf['backers'])
pltdf['backers_log'].hist(bins=100,log=True)
plt.figure()
pltdf['usd_pledged_real_log']=np.log(pltdf['usd_pledged_real'])
pltdf['usd_pledged_real_log'].hist(bins=100,log=True)
# pltdf['backers'].hist(log=True)
# pltdf['usd_pledged_real'].hist(log=True)
plt.figure()
df['yearlaunched'].hist(log=False,bins=100)
plt.figure()
df['launched'].hist(log=False,bins=100)
#df.hist(log=True)
plt2df = df[['usd_goal_real','backers','usd_pledged_real','durationdays','launched','state']].copy()
# plt2df['usd_goal_real']=np.log(plt2df['usd_goal_real'])
# plt2df['usd_pledged_real']=np.log(plt2df['usd_pledged_real'])
# plt2df['backers']=np.log(plt2df['backers'])
sns_plot=sns.pairplot(pltdf[0:50000], hue='state')

print(plt2df.corr())
# Out:
#                   usd_goal_real   backers  usd_pledged_real  durationdays
# usd_goal_real          1.000000  0.004517          0.005596     -0.015851
# backers                0.004517  1.000000          0.752539     -0.011547
# usd_pledged_real       0.005596  0.752539          1.000000     -0.016566
# durationdays          -0.015851 -0.011547         -0.016566      1.000000

# %% [markdown]
# #

# %%
raw_data = pd.read_csv('data.csv')
df = pd.DataFrame(raw_data)
list(raw_data.columns.values)
# Out:
# ['ID',
#  'name',
#  'category',
#  'main_category',
#  'currency',
#  'deadline',
#  'goal',
#  'launched',
#  'pledged',
#  'state',
#  'backers',
#  'country',
#  'usd pledged',
#  'usd_pledged_real',
#  'usd_goal_real']

# %%
plt.figure()
pltdf['usd_pledged_real'].hist()

s = pd.Series(pltdf['usd_pledged_real']>0, name='bools')

#Trying to sort all of the zero away...to take the log

withoutzeros=np.log(pltdf['usd_pledged_real'][s.values])

plt.figure()
withoutzeros.hist()

plt.figure()
pltdf['backers'].hist()
# for the other arribute
s1 = pd.Series(pltdf['backers']>0, name='bools')
withoutzeros2=np.log(pltdf['backers'][s1.values])
plt.figure()
withoutzeros.hist()
